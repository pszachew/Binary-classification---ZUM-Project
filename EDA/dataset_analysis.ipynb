# %%
import pandas as pd
import os
from utils import categorical_counptlot, continuous_histplot
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("../data/aug_train.csv")

# %% [markdown]
# ## VARIABLES TYPE

# %%
train.dtypes
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                 object
# company_size               object
# company_type               object
# last_new_job               object
# training_hours              int64
# target                    float64
# dtype: object

# %% [markdown]
# ## NULL PERCENTAGE

# %%
train.isna().sum()/len(train)*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     0.000000
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# last_new_job               2.207955
# training_hours             0.000000
# target                     0.000000
# dtype: float64

# %%
categoricals = ['gender', 'relevent_experience', 'education_level',
                'experience', 'company_type', 'major_discipline', 'last_new_job', 'company_size', 'enrolled_university', 'target']

# %%
discrete = ['training_hours']
continuous = ['city_development_index']

# %%
for col in categoricals:
    categorical_counptlot(train, (12,6), col)

# %%
for col in (discrete + continuous):
    continuous_histplot(train, (12, 6), col)
